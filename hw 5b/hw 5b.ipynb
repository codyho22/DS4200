# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv('Summer Olympic Medals.csv')

df
# Out:
#      Rank                  NOC  Gold  Silver  Bronze  Total
# 0     1.0  United States (USA)  1061     830     738   2629
# 1     2.0  Soviet Union (URS)*   395     319     296   1010
# 2     3.0  Great Britain (GBR)   284     318     314    916
# 3     4.0          China (CHN)   263     199     174    636
# 4     5.0         France (FRA)   223     251     277    751
# ..    ...                  ...   ...     ...     ...    ...
# 149   NaN        Eritrea (ERI)     0       0       1      1
# 150   NaN         Guyana (GUY)     0       0       1      1
# 151   NaN           Iraq (IRQ)     0       0       1      1
# 152   NaN      Mauritius (MRI)     0       0       1      1
# 153   NaN           Togo (TOG)     0       0       1      1
#
# [154 rows x 6 columns]

# %%
df_sorted = df.sort_values(by='Total', ascending=False)


df_long = df_sorted.melt(id_vars=['NOC'], value_vars=['Gold', 'Silver', 'Bronze'],
                  var_name='medal', value_name='count')

# Create the stacked bar chart
chart = alt.Chart(df_long).mark_bar().encode(
    x=alt.X('NOC:N', title='Country'),
    y=alt.Y('count:Q', title='Number of Medals'),
    color=alt.Color('medal:N', title='Medal Type', 
                    scale=alt.Scale(domain=['Gold', 'Silver', 'Bronze'],
                                    range=['#FFD700', '#C0C0C0', '#CD7F32']))
).properties(
    title='Olympic Medals by Country',
    width=1000,
    height=400
)

# Display the chart
chart
# Out:
# alt.Chart(...)
