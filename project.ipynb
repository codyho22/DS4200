# %%
import pandas as pd

df = pd.read_csv("Census Data.csv")

# %%
df
# Out:
#      Key for archaeology team ID code for specific households      Unnamed: 2  \
# 0                       Order                          Family  Original order
# 1                           1                         RES.006              99
# 2                           2                         RES.008             195
# 3                           3                         RES.009             278
# 4                           4                         RES.007             306
# ...                       ...                             ...             ...
# 1386                     1386                         RES.455             210
# 1387                     1387                         RES.451             346
# 1388                     1388                             NaN             NaN
# 1389                     1389                         RES.454             462
# 1390                     1390                         RES.456             433
#
# ...
